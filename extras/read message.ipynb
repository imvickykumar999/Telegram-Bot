# %% [markdown]
# # Download DP

# %%
import asyncio
from telethon import TelegramClient, events

session_name = "testingvicky"
api_id = '7131770'
api_hash = "5faaf123de1c860ab158c5217e703fc5"

async def main():
    async with TelegramClient(session_name, api_id, api_hash) as client:
        await client.send_message('me', 'Hello, myself!')
        print(await client.download_profile_photo('me'))

        @client.on(events.NewMessage(pattern='(?i).*Hello'))
        async def handler(event):
            await event.reply('Hey!')

        await client.run_until_disconnected()

# Only this line changes, the rest will work anywhere.
# Jupyter
await main()

# Otherwise
# asyncio.run(main())
# Out:
# Please enter your phone (or bot token): +918239957923
# Please enter the code you received: 35132
# Please enter your password: ········
# Signed in successfully as Vicky Kumar
# imvickykumar999.jpg

# %% [markdown]
# # Read Message

# %%
# imvickykumar

import requests
from pprint import pprint as p
bot_token = '1987325386:AAHeUN-nSUOV7uDDMWrh0nLoyjHh598I_F4'

req = requests.get(f'https://api.telegram.org/bot{bot_token}/getUpdates') 
show = req.json()

for i in list(show.values())[1]:
    p(i)
    print('-'*80)
# Out:
# {'message': {'chat': {'first_name': 'Vicky',
#                       'id': 931672788,
#                       'last_name': 'Kumar',
#                       'type': 'private',
#                       'username': 'imvickykumar999'},
#              'date': 1629735906,
#              'from': {'first_name': 'Vicky',
#                       'id': 931672788,
#                       'is_bot': False,
#                       'language_code': 'en',
#                       'last_name': 'Kumar',
#                       'username': 'imvickykumar999'},
#              'message_id': 3,
#              'text': 'Hi'},
#  'update_id': 21439506}
# --------------------------------------------------------------------------------
# {'message': {'chat': {'first_name': 'Vicky',
#                       'id': 931672788,
#                       'last_name': 'Kumar',
#                       'type': 'private',
#                       'username': 'imvickykumar999'},
#              'date': 1629736107,
# ...

# %%
# show

# %%
mess = show['result'][3]['message']
p(mess)
# Out:
# {'chat': {'first_name': 'Vicky',
#           'id': 931672788,
#           'last_name': 'Kumar',
#           'type': 'private',
#           'username': 'imvickykumar999'},
#  'date': 1629773572,
#  'from': {'first_name': 'Vicky',
#           'id': 931672788,
#           'is_bot': False,
#           'language_code': 'en',
#           'last_name': 'Kumar',
#           'username': 'imvickykumar999'},
#  'message_id': 6,
#  'text': "UserIsBotError: Bots can't send messages to other bots (caused by "
#          'SendMessageRequest)'}

# %%
mess['text']
# Out:
# "UserIsBotError: Bots can't send messages to other bots (caused by SendMessageRequest)"

# %%
mess.keys()
# Out:
# dict_keys(['message_id', 'from', 'chat', 'date', 'text'])

# %%
# imvickykumar999

import requests
from pprint import pprint as p

bot_token = '1980250795:AAHiOv4HSyy1hfU8IMWMNk_3BeycBgFpUPQ'
req = requests.get(f'https://api.telegram.org/bot{bot_token}/getUpdates') 
show = req.json()

for i in list(show.values())[1]:
    p(i)
    print('-'*80)
# Out:
# {'message': {'chat': {'first_name': 'Vicky',
#                       'id': 931672788,
#                       'last_name': 'Kumar',
#                       'type': 'private',
#                       'username': 'imvickykumar999'},
#              'date': 1629726994,
#              'entities': [{'length': 85, 'offset': 0, 'type': 'url'}],
#              'from': {'first_name': 'Vicky',
#                       'id': 931672788,
#                       'is_bot': False,
#                       'language_code': 'en',
#                       'last_name': 'Kumar',
#                       'username': 'imvickykumar999'},
#              'message_id': 15,
#              'text': 'https://api.telegram.org/bot1980250795:AAHiOv4HSyy1hfU8IMWMNk_3BeycBgFpUPQ/getUpdates'},
#  'update_id': 217191310}
# --------------------------------------------------------------------------------
# {'message': {'chat': {'first_name': 'Vicky',
#                       'id': 931672788,
# ...

# %% [markdown]
# # Write Message

# %%
# imvickykumar

bot_token = '1987325386:AAHeUN-nSUOV7uDDMWrh0nLoyjHh598I_F4'
bot_chatID = '931672788'
bot_message = 'hello ankit'

send_text = 'https://api.telegram.org/bot' + bot_token + '/sendMessage?chat_id=' + bot_chatID + '&parse_mode=Markdown&text=' + bot_message    
print(send_text)

import requests
x = requests.post(send_text)
x.text
# Out:
# https://api.telegram.org/bot1987325386:AAHeUN-nSUOV7uDDMWrh0nLoyjHh598I_F4/sendMessage?chat_id=931672788&parse_mode=Markdown&text=hello ankit
# '{"ok":true,"result":{"message_id":67,"from":{"id":1987325386,"is_bot":true,"first_name":"imvickykumar","username":"imvickykumarbot"},"chat":{"id":931672788,"first_name":"Vicky","last_name":"Kumar","username":"imvickykumar999","type":"private"},"date":1629785321,"text":"hello ankit"}}'

# %%
bot_token = '1980250795:AAHiOv4HSyy1hfU8IMWMNk_3BeycBgFpUPQ'
bot_chatID = '1277466776'
bot_message = 'hello badal'
send_text = 'https://api.telegram.org/bot' + bot_token + '/sendMessage?chat_id=' + bot_chatID + '&parse_mode=Markdown&text=' + bot_message    

print(send_text)

import requests
url = send_text
x = requests.post(url)
print(x.text)
# Out:
# https://api.telegram.org/bot1980250795:AAHiOv4HSyy1hfU8IMWMNk_3BeycBgFpUPQ/sendMessage?chat_id=1277466776&parse_mode=Markdown&text=hello badal
# {"ok":true,"result":{"message_id":56,"from":{"id":1980250795,"is_bot":true,"first_name":"Vicky Kumar","username":"imvickykumar999bot"},"chat":{"id":1277466776,"first_name":"Bd","last_name":"Chaudhary","type":"private"},"date":1629785523,"text":"hello badal"}}

# %%
print('https://api.telegram.org/bot1987325386:AAHeUN-nSUOV7uDDMWrh0nLoyjHh598I_F4/sendMessage?chat_id=931672788&parse_mode=Markdown&text=i%20am%20vix,%20testing%20bot')
# Out:
# https://api.telegram.org/bot1987325386:AAHeUN-nSUOV7uDDMWrh0nLoyjHh598I_F4/sendMessage?chat_id=931672788&parse_mode=Markdown&text=i%20am%20vix,%20testing%20bot

# %% [markdown]
# # Send Whatsapp Message

# %%
url = 'https://api.whatsapp.com/send?phone=918239957923&text=What%20is%20Correct%20Password%20to%20watch%20Bell%20Bottom%20on%20your%20website%20?'      

import requests
x = requests.post(url)
# print(x.text)
print(url)

# whatsapp does not send message without pressing enter.
# Out:
# https://api.whatsapp.com/send?phone=918239957923&text=What%20is%20Correct%20Password%20to%20watch%20Bell%20Bottom%20on%20your%20website%20?

# %%
import requests
from pprint import pprint as p
req = requests.get('https://api.telegram.org/bot1980250795:AAHiOv4HSyy1hfU8IMWMNk_3BeycBgFpUPQ/getUpdates') 
show = req.json()

for i in list(show.values())[1]:
    p(i)
    print('-'*80)
# Out:
# {'message': {'chat': {'first_name': 'Vicky',
#                       'id': 931672788,
#                       'last_name': 'Kumar',
#                       'type': 'private',
#                       'username': 'imvickykumar999'},
#              'date': 1629726994,
#              'entities': [{'length': 85, 'offset': 0, 'type': 'url'}],
#              'from': {'first_name': 'Vicky',
#                       'id': 931672788,
#                       'is_bot': False,
#                       'language_code': 'en',
#                       'last_name': 'Kumar',
#                       'username': 'imvickykumar999'},
#              'message_id': 15,
#              'text': 'https://api.telegram.org/bot1980250795:AAHiOv4HSyy1hfU8IMWMNk_3BeycBgFpUPQ/getUpdates'},
#  'update_id': 217191310}
# --------------------------------------------------------------------------------
# {'message': {'chat': {'first_name': 'Vicky',
#                       'id': 931672788,
# ...

# %%
show
# Out:
# {'ok': True,
#  'result': [{'update_id': 217191310,
#    'message': {'message_id': 15,
#     'from': {'id': 931672788,
#      'is_bot': False,
#      'first_name': 'Vicky',
#      'last_name': 'Kumar',
#      'username': 'imvickykumar999',
#      'language_code': 'en'},
#     'chat': {'id': 931672788,
#      'first_name': 'Vicky',
#      'last_name': 'Kumar',
#      'username': 'imvickykumar999',
#      'type': 'private'},
#     'date': 1629726994,
#     'text': 'https://api.telegram.org/bot1980250795:AAHiOv4HSyy1hfU8IMWMNk_3BeycBgFpUPQ/getUpdates',
#     'entities': [{'offset': 0, 'length': 85, 'type': 'url'}]}},
#   {'update_id': 217191311,
#    'message': {'message_id': 16,
#     'from': {'id': 931672788,
#      'is_bot': False,
#      'first_name': 'Vicky',
#      'last_name': 'Kumar',
#      'username': 'imvickykumar999',
#      'language_code': 'en'},
#     'chat': {'id': 931672788,
#      'first_name': 'Vicky',
#      'last_name': 'Kumar',
# ...

# %%
mess = show['result'][3]['message']
mess
# Out:
# {'message_id': 18,
#  'from': {'id': 931672788,
#   'is_bot': False,
#   'first_name': 'Vicky',
#   'last_name': 'Kumar',
#   'username': 'imvickykumar999',
#   'language_code': 'en'},
#  'chat': {'id': 931672788,
#   'first_name': 'Vicky',
#   'last_name': 'Kumar',
#   'username': 'imvickykumar999',
#   'type': 'private'},
#  'date': 1629727894,
#  'text': 'badal'}

# %%
mess['text']
# Out:
# 'badal'

# %%
mess.keys()
# Out:
# dict_keys(['message_id', 'from', 'chat', 'date', 'text'])

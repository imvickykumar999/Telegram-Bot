# %% [markdown]
# # Read Message

# %%
import requests
from pprint import pprint as p
bot_token = '1987325386:AAHeUN-nSUOV7uDDMWrh0nLoyjHh598I_F4'

req = requests.get(f'https://api.telegram.org/bot{bot_token}/getUpdates') 
show = req.json()

for i in list(show.values())[1]:
    p(i)
    print('-'*80)
# Out:
# {'message': {'chat': {'first_name': 'Vicky',
#                       'id': 931672788,
#                       'last_name': 'Kumar',
#                       'type': 'private',
#                       'username': 'imvickykumar999'},
#              'date': 1629735906,
#              'from': {'first_name': 'Vicky',
#                       'id': 931672788,
#                       'is_bot': False,
#                       'language_code': 'en',
#                       'last_name': 'Kumar',
#                       'username': 'imvickykumar999'},
#              'message_id': 3,
#              'text': 'Hi'},
#  'update_id': 21439506}
# --------------------------------------------------------------------------------
# {'message': {'chat': {'first_name': 'Vicky',
#                       'id': 931672788,
#                       'last_name': 'Kumar',
#                       'type': 'private',
#                       'username': 'imvickykumar999'},
#              'date': 1629736107,
# ...

# %%
# show

# %%
mess = show['result'][3]['message']
p(mess)
# Out:
# {'chat': {'first_name': 'Vicky',
#           'id': 931672788,
#           'last_name': 'Kumar',
#           'type': 'private',
#           'username': 'imvickykumar999'},
#  'date': 1629773572,
#  'from': {'first_name': 'Vicky',
#           'id': 931672788,
#           'is_bot': False,
#           'language_code': 'en',
#           'last_name': 'Kumar',
#           'username': 'imvickykumar999'},
#  'message_id': 6,
#  'text': "UserIsBotError: Bots can't send messages to other bots (caused by "
#          'SendMessageRequest)'}

# %%
mess['text']
# Out:
# "UserIsBotError: Bots can't send messages to other bots (caused by SendMessageRequest)"

# %%
mess.keys()
# Out:
# dict_keys(['message_id', 'from', 'chat', 'date', 'text'])

# %%
import requests
from pprint import pprint as p

bot_token = '1980250795:AAHiOv4HSyy1hfU8IMWMNk_3BeycBgFpUPQ'
req = requests.get(f'https://api.telegram.org/bot{bot_token}/getUpdates') 
show = req.json()

for i in list(show.values())[1]:
    p(i)
    print('-'*80)
# Out:
# {'message': {'chat': {'first_name': 'Vicky',
#                       'id': 931672788,
#                       'last_name': 'Kumar',
#                       'type': 'private',
#                       'username': 'imvickykumar999'},
#              'date': 1629726994,
#              'entities': [{'length': 85, 'offset': 0, 'type': 'url'}],
#              'from': {'first_name': 'Vicky',
#                       'id': 931672788,
#                       'is_bot': False,
#                       'language_code': 'en',
#                       'last_name': 'Kumar',
#                       'username': 'imvickykumar999'},
#              'message_id': 15,
#              'text': 'https://api.telegram.org/bot1980250795:AAHiOv4HSyy1hfU8IMWMNk_3BeycBgFpUPQ/getUpdates'},
#  'update_id': 217191310}
# --------------------------------------------------------------------------------
# {'message': {'chat': {'first_name': 'Vicky',
#                       'id': 931672788,
# ...

# %% [markdown]
# # Write Message

# %%
import requests

bot_token = '1987325386:AAHeUN-nSUOV7uDDMWrh0nLoyjHh598I_F4'
bot_chatID = '931672788'
bot_message = 'i am vix, testing bot'
send_text = 'https://api.telegram.org/bot' + bot_token + '/sendMessage?chat_id=' + bot_chatID + '&parse_mode=Markdown&text=' + bot_message    

url = send_text
x = requests.post(url)
x.text
# Out:
# '{"ok":true,"result":{"message_id":21,"from":{"id":1987325386,"is_bot":true,"first_name":"imvickykumar","username":"imvickykumarbot"},"chat":{"id":931672788,"first_name":"Vicky","last_name":"Kumar","username":"imvickykumar999","type":"private"},"date":1629776229,"text":"i am vix, testing bot"}}'

# %%
bot_token = '1980250795:AAHiOv4HSyy1hfU8IMWMNk_3BeycBgFpUPQ'
bot_chatID = '1277466776'
bot_message = 'i am vix testing bot'
send_text = 'https://api.telegram.org/bot' + bot_token + '/sendMessage?chat_id=' + bot_chatID + '&parse_mode=Markdown&text=' + bot_message    

import requests
url = send_text
x = requests.post(url)
print(x.text)
# Out:
# {"ok":true,"result":{"message_id":32,"from":{"id":1980250795,"is_bot":true,"first_name":"Vicky Kumar","username":"imvickykumar999bot"},"chat":{"id":1277466776,"first_name":"Bd","last_name":"Chaudhary","type":"private"},"date":1629776229,"text":"i am vix testing bot"}}
